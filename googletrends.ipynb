# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import datetime

# %%
from pytrends.request import TrendReq

pytrends = TrendReq(hl='en-US', tz=360)

# %%
kw_list = ["Football","Rugby","Tennis"]
pytrends.build_payload(kw_list, timeframe='today 3-m')

# %%
historicaldf = pytrends.interest_over_time()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)

# %%
historicaldf.dropna(how='all',axis=0, inplace=True)

# %%
display(historicaldf)
# Out:
#             Football  Rugby  Tennis  isPartial
# date
# 2024-03-18        36      8      17      False
# 2024-03-19        34      7      16      False
# 2024-03-20        39      7      17      False
# 2024-03-21        52      7      16      False
# 2024-03-22        49     10      17      False
# ...              ...    ...     ...        ...
# 2024-06-14        67      9      19      False
# 2024-06-15        84     14      20      False
# 2024-06-16       100     11      22      False
# 2024-06-17        69      7      21      False
# 2024-06-18        75      6      20       True
#
# [93 rows x 4 columns]

# %%
historicaldf.plot(y=kw_list,
        kind="line", figsize=(10, 10), xlabel = 'month', ylabel = 'search share')
# Out:
# <Axes: xlabel='month', ylabel='search share'>
